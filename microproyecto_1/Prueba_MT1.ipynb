# %%
import pandas as pd
import cv2

imagen = cv2.imread('data/images/rembrandt_self-portrait-1637.jpg')
#cv2.imshow("Rembrandt",imagen)
#cv2.waitKey(0)

imagen_rgb=cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
imagen
imagen_rgb
# Out:
# array([[[217, 218, 213],
#         [217, 218, 213],
#         [217, 218, 213],
#         ...,
#         [216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211]],
#
#        [[217, 218, 213],
#         [217, 218, 213],
#         [217, 218, 213],
#         ...,
#         [216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211]],
#
#        [[217, 218, 213],
#         [217, 218, 213],
#         [217, 218, 213],
#         ...,
#         [216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211]],
#
#        ...,
#
#        [[216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211],
#         ...,
#         [216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211]],
#
#        [[216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211],
#         ...,
#         [216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211]],
#
#        [[216, 217, 211],
#         [216, 217, 211],
#         [216, 217, 211],
# ...

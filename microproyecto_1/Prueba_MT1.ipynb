# %%
import pandas as pd
import cv2

imagen = cv2.imread('data/images/rembrandt_self-portrait-1637.jpg')
cv2.imshow("Rembrand",imagen)
cv2.waitKey(0)
# Out:
#   Cell In[8], line 4
#     imagen = cv2.imread(data/images/rembrandt_self-portrait-1637.jpg')
#                                                                  ^
# SyntaxError: invalid imaginary literal
